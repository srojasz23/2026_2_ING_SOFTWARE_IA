# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as ss
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv("application_record.csv")

# %%
data.shape
# Out:
# (438557, 18)

# %%
data = data.sample(5000)

# %%
data.shape
# Out:
# (5000, 18)

# %%
data.head()
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 319465  6264439           F            N               Y             0
# 4896    5024370           F            N               N             0
# 28916   5706579           F            N               Y             1
# 345363  6800280           M            Y               Y             0
# 186452  5860917           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 319465          202500.0             Pensioner  Secondary / secondary special
# 4896            112500.0             Pensioner  Secondary / secondary special
# 28916           135000.0               Working  Secondary / secondary special
# 345363          405000.0  Commercial associate               Higher education
# 186452          270000.0             Pensioner  Secondary / secondary special
#
# ...

# %%
data = data.drop('DAYS_BIRTH', axis=1)

# %%
data = data.drop('DAYS_EMPLOYED', axis=1)

# %%
data.head()
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 319465  6264439           F            N               Y             0
# 4896    5024370           F            N               N             0
# 28916   5706579           F            N               Y             1
# 345363  6800280           M            Y               Y             0
# 186452  5860917           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 319465          202500.0             Pensioner  Secondary / secondary special
# 4896            112500.0             Pensioner  Secondary / secondary special
# 28916           135000.0               Working  Secondary / secondary special
# 345363          405000.0  Commercial associate               Higher education
# 186452          270000.0             Pensioner  Secondary / secondary special
#
# ...

# %%
data.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# FLAG_MOBIL               int64
# FLAG_WORK_PHONE          int64
# FLAG_PHONE               int64
# FLAG_EMAIL               int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
data['FLAG_MOBIL'] = data.FLAG_MOBIL.astype(object)
data['FLAG_WORK_PHONE'] = data.FLAG_WORK_PHONE.astype(object)
data['FLAG_PHONE'] = data.FLAG_PHONE.astype(object)
data['FLAG_EMAIL'] = data.FLAG_EMAIL.astype(object)

# %%
data.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# FLAG_MOBIL              object
# FLAG_WORK_PHONE         object
# FLAG_PHONE              object
# FLAG_EMAIL              object
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 319465 to 338847
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   CODE_GENDER          5000 non-null   object
#  2   FLAG_OWN_CAR         5000 non-null   object
#  3   FLAG_OWN_REALTY      5000 non-null   object
#  4   CNT_CHILDREN         5000 non-null   int64
#  5   AMT_INCOME_TOTAL     5000 non-null   float64
#  6   NAME_INCOME_TYPE     5000 non-null   object
#  7   NAME_EDUCATION_TYPE  5000 non-null   object
#  8   NAME_FAMILY_STATUS   5000 non-null   object
#  9   NAME_HOUSING_TYPE    5000 non-null   object
#  10  FLAG_MOBIL           5000 non-null   object
#  11  FLAG_WORK_PHONE      5000 non-null   object
#  12  FLAG_PHONE           5000 non-null   object
#  13  FLAG_EMAIL           5000 non-null   object
#  14  OCCUPATION_TYPE      3480 non-null   object
# ...

# %%
# Analisis univariado
# calcula la media 
data['AMT_INCOME_TOTAL'].mean()
# Out:
# np.float64(187413.462)

# %%
#calcular la mediana 
data['AMT_INCOME_TOTAL'].median()
# Out:
# 157500.0

# %%
#calcular los cuartiles 
data['AMT_INCOME_TOTAL'].quantile()
# Out:
# np.float64(157500.0)

# %%
#cacular moda
data['AMT_INCOME_TOTAL'].mode()
# Out:
# 0    135000.0
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
#calcular los cuartiles 
data['AMT_INCOME_TOTAL'].quantile([0])
# Out:
# 0.0    27000.0
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
#calcular los cuartiles 
data['AMT_INCOME_TOTAL'].quantile([1])
# Out:
# 1.0    3150000.0
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
#calcular los cuartiles 
data['AMT_INCOME_TOTAL'].quantile([0.25])
# Out:
# 0.25    126000.0
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
#calcular los cuartiles 
data['AMT_INCOME_TOTAL'].quantile([0.45])
# Out:
# 0.45    157500.0
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
#calcula decil
data['AMT_INCOME_TOTAL'].quantile([0.10])
# Out:
# 0.1    90000.0
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
#rango 
data['AMT_INCOME_TOTAL'].min()
# Out:
# 27000.0

# %%
data['AMT_INCOME_TOTAL'].max()
# Out:
# 3150000.0

# %%
data['AMT_INCOME_TOTAL'].max()-data['AMT_INCOME_TOTAL'].min()
# Out:
# 3123000.0

# %%
#Rango
data['CNT_CHILDREN'].min()
# Out:
# 0

# %%
data['CNT_CHILDREN'].var() # varianza
# Out:
# 0.5195048609721686

# %%
data['CNT_CHILDREN'].std() #desviancion estandar
# Out:
# 0.7207668561831687

# %%
data['AMT_INCOME_TOTAL'].std()
# Out:
# 108881.30518342044

# %%
data['AMT_INCOME_TOTAL'].std(ddof=0) # poblacional
# Out:
# 108870.41650844114

# %% [markdown]
# # tarea: investigar varianza, desviacion estandar, cuartiles, deciles, poblacional, coeficiente de variacion,muestral coefeciente de curtosis  coeficiente de asimetria , shapiro, Prueba de normalidad

# %%
data['AMT_INCOME_TOTAL'].std(ddof=0) # poblacional
# Out:
# 108870.41650844114

# %%
data['AMT_INCOME_TOTAL'].std(ddof=1) #muestral
# Out:
# 108881.30518342044

# %%
#coeficiente de variacion AMT_INCOME_TOTAL
data['AMT_INCOME_TOTAL'].std(ddof=0)/data['AMT_INCOME_TOTAL'].mean()
# Out:
# np.float64(0.5809103324095317)

# %%
##coeficiente de variacion  CNT_CHILDREN
data['CNT_CHILDREN'].std(ddof=0)/data['CNT_CHILDREN'].mean()
# Out:
# np.float64(1.656008216666718)

# %%
# coeficiente de asimetria 
ss.skew(data['AMT_INCOME_TOTAL'])
# Out:
# np.float64(6.329855435746971)

# %%
# coefeciente de curtosis 
ss.kurtosis(data['AMT_INCOME_TOTAL'])
# Out:
# np.float64(122.90695670639097)

# %%
# resumen 
data['AMT_INCOME_TOTAL'].describe()
# Out:
# count    5.000000e+03
# mean     1.874135e+05
# std      1.088813e+05
# min      2.700000e+04
# 25%      1.260000e+05
# 50%      1.575000e+05
# 75%      2.250000e+05
# max      3.150000e+06
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
# Prueba de normalidad 
# como el pvalue < 5%, se rechaza HO  SI AL 95% de confianza se concluye que los ingresos anuales 
# de los clientes no se aproximan a la normalidad 
ss.shapiro(data.AMT_INCOME_TOTAL)
# Out:
# ShapiroResult(statistic=np.float64(0.716486860893194), pvalue=np.float64(2.315375728892843e-68))

# %%
ss.normaltest(data.AMT_INCOME_TOTAL)
# Out:
# NormaltestResult(statistic=np.float64(6268.148902155819), pvalue=np.float64(0.0))

# %%
ss.shapiro(data.CNT_CHILDREN)
# Out:
# ShapiroResult(statistic=np.float64(0.6400945908200788), pvalue=np.float64(3.3475939924039264e-73))

# %%
ss.shapiro(data.CNT_FAM_MEMBERS)
# Out:
# ShapiroResult(statistic=np.float64(0.8371098515886655), pvalue=np.float64(8.956760744734274e-58))
